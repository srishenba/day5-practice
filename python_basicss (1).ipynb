# %%
print("lotus")
print("'srima'")
# Out:
# lotus
# 'srima'

# %% [markdown]
# # New Section

# %%
name=input()
age=input()
college=input()
print(f"my name is {name}")
print(f"my age is {age}")
print(f"my college is {college}")
# Out:
# ggg
# 77
# fgj
# my name is ggg
# my age is 77
# my college is fgj

# %% [markdown]
# # New Section

# %%
height=float(input())
print(f"your height is{height}")
# Out:
# 7.5
# your height is7.5

# %% [markdown]
# # New Section

# %%
name="varun"
age=33
height=4.4
print(f"The type of name is: {type(name)}")
print(f"The type of age is: {type(age)}")
print(f"The type of height is: {type(height)}")
# Out:
# The type of name is: <class 'str'>
# The type of age is: <class 'int'>
# The type of height is: <class 'float'>

# %% [markdown]
# # New Section

# %%
celsisus=float(input("enter celsius:"))
fahrenheit=(celsisus*9/5)+32
print(f"fahrenheit is:{fahrenheit}")
# Out:
# enter celsius:7.8
# fahrenheit is:46.04

# %% [markdown]
# # New Section

# %%
name=str(input())
rollno=int(input())
dept=str(input())
cgpa=float(input())
print(f"my name is {name}")
print(f"my roll no is {rollno}")
print(f"my college is {dept}")
print(f"my cgpa is{cgpa}")
# Out:
# devi
# 66
# cde
# 8.0
# my name is devi
# my roll no is 66
# my college is cde
# my cgpa is8.0

# %% [markdown]
# # New Section

# %%
p=int(input("enter the value of p:"))
r=int(input("enter the value of r:"))
t=int(input("enter the value of t:"))
si=(p*r*t)/100
print(f"simple interest is:{si}")
# Out:
# enter the value of p:90
# enter the value of r:70
# enter the value of t:69
# simple interest is:4347.0

# %% [markdown]
# # New Section

# %%
num1="100"
num2="50"
a=num1+num2
print(a)
# Out:
# 10050

# %% [markdown]
# # New Section

# %%
name=str(input("my name is:"))
age=int(input("my age is:"))
city=str(input("my city:"))
skill=str(input("my skill is:"))
print(f"my name is {name}")
print(f"my age is {age}")
print(f"my city is {city}")
print(f"my skill is {skill}")
# Out:
# my name is:shenba
# my age is:21
# my cityis:madurai
# my skill is:python
# my name is shenba
# my age is 21
# my city is madurai
# my skill is python

# %% [markdown]
# # New Section

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))
c=a+b
d=a-b
e=a*b
f=a/b
print(f"addition is:{c}")
print(f"subtraction is:{d}")
print(f"multiplication is:{e}")
print(f"division is:{f}")
# Out:
# enter the value of a:10
# enter the value of b:90
# addition is:100
# subtraction is:-80
# multiplication is:900
# division is:0.1111111111111111

# %% [markdown]
# # New Section

# %%
 name=str(input("enter the student name:"))
 tamil=int(input("enter the tamil marks:"))
 english=int(input("enter the english marks:"))
 maths=int(input("enter the maths marks:"))
 science=int(input("enter the science marks:"))
 social=int(input("enter the social marks:"))
 total=tamil+english+maths+science+social
 average=total/5
 print(f"the total marks is:{total}")
 print(f"the average marks is:{average}")
# Out:
# enter the student name:shenba
# enter the tamil marks:90
# enter the english marks:70
# enter the maths marks:60
# enter the science marks:90
# enter the social marks:50
# the total marks is:360
# the average marks is:72.0

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))
total=a+b
print(total)
# Out:
# enter the value of a:10
# enter the value of b:90
# 100
